# %% [markdown]
# <a href="https://colab.research.google.com/github/liviacardoso-collab/INTED_2025/blob/main/liviacardoso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
num=int(input('digite um número:'))
if num>10:
   print(num, 'é maior que 10!')
elif num<10:
   print(num, 'é menor que 10!')
else:
   print(num, 'é 10!!!')
# Out:
# digite um número:12
# 12 é maior que 10!

# %%
#2
num=int(input("digite um número:"))
if num%2==0:
   print("par")
# Out:
# digite um número:16
# par

# %%
#3
nome=input('digite um nome')
if 'a' in nome:
 print('contém a')
# Out:
# digite um nomelívia
# contém a

# %%
#4
num=int(input("digite um número:"))
if num%5==0:
 print('múltiplo')
# Out:
# digite um número:10
# múltiplo

# %%
#5
num=int(input('digite a temperatura'))
if num>30:
  print(num,'quente')
elif num<30:
  print("frio")
# Out:
# digite a temperatura34
# 34 quente

# %%
#6
letra= input('S para sair e N para continuar')
if letra.lower()=='s':
 print('sair')
if letra.lower()=='n':
 print('continuar')
else:
  print('opção inválida')
# Out:
# S para sair e N para continuarS
# sair
# opção inválida

# %%
#7
num=int(input("digite um número"))
if num<0:
  print(num, 'negativo')
elif num>0:
  print(num,'positivo')
else:
  print(num, 'zero')
# Out:
# digite um número10
# 10 positivo

# %%
#8

# %%
#9
